# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

with open('losses.pkl', 'rb') as f:
    losses = pickle.load(f)

# Ora 'losses' è un dizionario con le tue loss
train_loss = losses['loss']
val_loss = losses['val_loss']


# Creiamo il plot
plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss inserire nome modello')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

with open('losses.pkl', 'rb') as f:
    losses = pickle.load(f)

# Ora 'losses' è un dizionario con le tue loss
train_loss = losses['accuracy']
val_loss = losses['val_accuracy']



# Creiamo il plot
plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Accuracy')
plt.plot(val_loss, label='Validation Accuracy')
plt.title('Training and Validation Accuracy inserire nome modello')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
